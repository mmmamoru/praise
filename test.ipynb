# %%
# cd Documents/streamlit/W01
# streamlit run app.py

import numpy as np
import pandas as pd
import re
import streamlit as st

# %%
p_df = pd.read_csv('title_lyrics.csv', encoding='utf-8').dropna()
p_df
# Out:
#         title                                               body
# 0       主は実践だ  主は　わが主は 言葉だけでなく　日昇り沈むまで 実践だ　実践した しるしの歴史だ　奇跡の歴史...
# 1       約束の実践  あなたに神が約束しても パーセント為した時に成就する 行なっただけ　万事成されてゆく 行なわ...
# 2        許しと愛  主よわが罪　許してください 許して主のものにしてください そのままなら死の道行 ゆ く　 許...
# 3    やることは多いが  やること多いが 時間は理由がない 今日も勤しみ 走り走れ 神は構想 われは実践だ 日暮れ前 ...
# 4       夢を成す道  今日も私 日が昇り沈むまで 運動場 回り あちこち走って 駆け巡り 飛び回った  神様 見ら...
# ..        ...                                                ...
# 155     祈りなさい  あなたのための祈りが 成されたように 人々のため祈れば成される 　 祈りを信仰に堅くたち 深...
# 156    永遠な愛の生  神様に 栄光だ 聖霊様に 栄光だ 神様に 栄光 栄光 帰そう 帰そう 賛美の歴史だ 歌って ...
# 157      永遠な愛  聖霊様 神様 心から愛します わが愛は 真実な愛です なぜ　好きだからです 　 あまりに好き...
# 158         縁  袖が触れても 縁なのに 肌が触れたら ただの縁だろうか 運命だ　運命だ 　 袖が触れれば 十...
# 159   行なうとおりに  幸せに生きるのだ 本当に 素敵に生きよう 人生を本当に努力し いそしみ 熱心に走り生きよう ...
#
# [159 rows x 2 columns]

# %%
def search_praise(word):
    dic = {}

    for index, row in p_df.iterrows():
        
        text_ls = re.split("(?<=。)", row['body'].replace("\n", "").replace("\t", "").replace("\r", "").replace("\u3000", ""))

        for i in range(0, len(text_ls)):
            if text_ls[i].find(word) >= 0:
                dic[index] = {
                    'title' : row['title']
                    , 'body' : row['body']
                    }

    return pd.DataFrame(data=dic).T.sort_values('body')
# Out:
#                     title                                               body
# 3                やることは多いが  やること多いが 時間は理由がない 今日も勤しみ 走り走れ 神は構想 われは実践だ 日暮れ前 ...
# 89            神様が構想した 年の宮  ペクトゥ山 クムガン山脈 テベク山に延びて その山脈が チャリョン山脈 ノリョン山脈に 力強...
# 45                    滝の愛  一筋の滝のように 乱れもせず わが愛 天のため 流れ落ちた 滝のような わが愛は 変わらず ...
# 16                 御座 野心作  夏の 梅雨の雨は 一日 ざあざあと 降り注ぐが ああ われら 千年の宮のため 岩の造形 笑い...
# 8           願われるとおりになさるから  神様 御子 願うとおりなさり 外も中も 神秘で美しい 神の構想 傑作品だ 自分中心 捨てたら...
# 7    『 願われるとおりになさるから 仮題 』  神様、御子 願われるとおりになさるから 外も中も美しく 神秘的な 神様の構想 大傑作品だ。 ...
# 106           神様の歴史は聖地で輝く  雄大でもある 実に美しくもあるのだな 神秘なる神様の 構想だ その姿 誰が見ても 感嘆する ...

# %%
try:
        
    st.title('検索')
    search_word = st.text_input('**検索ワード**', '')
    if search_word != '':
        s_df = search_praise(search_word)
        for index, row in s_df.iterrows():
            st.write('タイトル: ', row['title'])
            expander = st.expander('全文表示')
            expander.write(row['body'])
            st.write('------------------------------------------------------------')

except KeyError:
    st.error('検索が引っかからなかったようです。', icon="🤷‍♀️")
